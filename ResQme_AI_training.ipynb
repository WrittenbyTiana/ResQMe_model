# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB  
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# Load dataset
data = pd.read_csv("Resqme_raw_data.csv")
X = data['Message']
Y = data['Severity']
# Split dataset

X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size=0.2, random_state=42)

# Build model
model = Pipeline([('vectorizer', TfidfVectorizer()),('classifier', MultinomialNB())])
                  
# Train model
model.fit(X_train, Y_train)

# Test model
predictions = model.predict(X_test)

print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#     Critical       0.80      0.93      0.86        30
#          Low       0.93      0.81      0.87        16
#       Medium       0.73      0.57      0.64        14
#
#     accuracy                           0.82        60
#    macro avg       0.82      0.77      0.79        60
# weighted avg       0.82      0.82      0.81        60

# %%
model.predict(['Heavy bleeding'])
# Out:
# array(['Critical'], dtype='<U8')

# %%
model.predict(['Bruises'])
# Out:
# array(['Low'], dtype='<U8')

# %%
model.predict(['The person still dey stable'])
# Out:
# array(['Low'], dtype='<U8')

# %%
model.predict(['The person break one hand'])
# Out:
# array(['Low'], dtype='<U8')

# %%
model.predict(['E be like the person need to go hospital'])
# Out:
# array(['Medium'], dtype='<U8')

# %%
model.predict(['E be like say the person break bone for neck o'])
# Out:
# array(['Medium'], dtype='<U8')

# %%
import pickle
pickle.dump(model, open('ResqMe_model.pkl', 'wb'))

# %%
model.predict(['An accident just happened here, but the victim is stable with minor bruises'])
# Out:
# array(['Low'], dtype='<U8')

# %%
model.predict(['An accidented victim with a broken bone'])
# Out:
# array(['Medium'], dtype='<U8')

# %%
model.predict(['An unconscious accident victim who is bleeding heavily'])
# Out:
# array(['Critical'], dtype='<U8')

# %%
# Out:
# array(['Critical'], dtype='<U8')

# %%
import joblib 
# Save the trained model to a file 
joblib.dump(model, "severity_model.pkl") 
print("Model saved successfully!")
# Out:
# Model saved successfully!
